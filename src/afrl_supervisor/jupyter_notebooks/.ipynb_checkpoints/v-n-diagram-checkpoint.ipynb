# %%
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt
import matplotlib.axis as axis
import numpy as np
import math

# %%
a0 = 0.05984281113
cla = 4.752798721
cda = 0.6417112299
alpha_stall = np.rad2deg(0.3391428111)
alpha_stallR = 0.3391428111
cla_stall = -3.85
cda_stall = -0.9233984055
area = 0.6
air_density = 1.2041
g = 9.81

# %%
# this generates C_L alpha curve
def coefficientLift(cla, alpha, alpha0):
        Cl = cla*(alpha - alpha0)
        return Cl

def dynamic_pressure(rho, v):
    Q = .5 * rho * (v*v)
    return Q    
    
def lift(cl, Q, S):
    L = cl * Q * S
    return L

def velocity(lift, cl, s, rho):
    V = np.sqrt((2 * lift) / (cl * s * rho))
    return V

# %%
# fills coeff of lift and angle list 
clList = []
angleList = []
for angle in range(0, 20):
    cl = coefficientLift(cla, angle, a0)
    clList.append(cl)
    angleList.append(angle)

# %%
plt.plot(clList, angleList, label = '1', -bo')
plt.plot(a0, alpha_stall, label = '1', '-bo')
plt.plot(a0, alpha_stall, label = '1', '-bo')

# plt.spines['bottom'].set_visible(False)
plt.axhline(0, color='black', lw=0.5)
plt.xlim(0,50) 
plt.axvline(x=alpha_stall, color='r', linestyle='--')
plt.xlabel('Velocity')

plt.ylim(-3,3) 
plt.ylabel('g')

plt.title('Load Factor vs. Speed')
plt.grid(False)
plt.show()
